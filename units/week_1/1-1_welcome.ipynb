# %% [markdown]
# <center><b>CTS2000: Scripting for the Humanities</b></center>
# <center>1-1: Welcome!</center>
#
# ---

# %% [markdown]
# <tr>
#     <td> <img src="../../Img/dhlogo.png" width="200" alt="" style="width: 300px;"/> </td>
#     <td> <img src="../../Img/dhsummer.png" width="200" alt="" style="width: 300px;"/> </td>
#     <td> <img src="../../Img/dlablogo1.png" width="200" alt="" style="width: 300px;"/> </td>
#     </tr>

# %% [markdown]
# # Welcome to CTS2000: Scripting for the Humanities!
#
# This course introduces students to core concepts in data creation, representation, and interpretation. In addition to thinking critically about the data as a form of representation, students will also analyse the ethical considerations of data and develop a number of models for the ethical contextualization of data. Students will learn to model data in software, understand the history of the concept of data, develop a data schema, understand differences between data and capta, and critique data as representation. Students will develop basic programming skills in Python programming languages. They will create data structures, use programming libraries to manipulate and work with data, and develop their own functions. The midterm project will introduce students to literature review and code reproduction. The final project is a group project designed to teach students how to work collaboratively and develop a digital humanities project from scratch, from ideation to dataset selection, from comprehensive literature review to a final paper and code submission.

# %% [markdown]
# # Introductions
#
# - What is your name and what are your pronouns?
# - What is your academic discipline?
# - What languages do you work with?
# - What is your experience with coding?
# - What is your experience with (digital) humanities?
# - What are your learning goals for this class?

# %% [markdown]
# # Learning Goals
#
# The successful completion of this course will enable the student to:
# - Gain an understanding of computational and humanistic questions, as well as their intersections
# - Model information and forms of representation as data.
# - Critically evaluate multiple forms of data.
# - Discuss data structures and basic algorithms.
# - Program in Python using datasets, data structures, libraries, and functions.
# - Use Python to collect content, encode it as data, and analyze it.
# - Work collaboratively and independently on computational research projects

# %% [markdown]
# # Why learn Python?
#
# **1. What is a programming language?**
# A [programming language](https://en.wikipedia.org/wiki/Programming_language) is a way to give instructions to a computer.
#
# **2. What is Python?**
# [Python is](https://en.wikipedia.org/wiki/Python_(programming_language)) a programming language!
#
# **3. What is (are) data?**
# ["Data is (are) a set of values](https://en.wikipedia.org/wiki/Data) of subjects with respect to qualitative or quantitative variables."
#
# **4. Why learn to program?**
# To think like a programmer means that you train to become a code detective, a resourceful Google searcher, and believe that all problems have at least one solution.
#
#
# - _Practical Efficiency:_ Although the initial learning curve can be frustrating, learning to program can save you lots of time doing basic tasks that you would otherwise have to do by hand.
#
#
# - _New Tools:_ Some things are literally impossible to do by hand and computers open the door to new tools and methods, with programming as the way to interact with them.
#
#
# - _New Data:_ Programming knowledge is required to access the wealth of new data in the 21st Century from [APIs](https://en.wikipedia.org/wiki/Application_programming_interface), websites, and social media.
#
#
# - _Better Science:_ This combination of efficiency, tools, and data has the ability to better create transparency, reproducibility, and collaboration that can lead to better science.

# %% [markdown]
# # GitHub
#
# We will use **GitHub** for the coding components of this class, starting in Week 4. There is a bit of a learning curve to using GitHub and often a less than smooth onboarding process in connecting to a GitHub repository with VS Code, especially when setting up Python and the environment packages. It's ok if this is all new to you. We will talk about this in more detail and actually go through the set up process in Week 4.
#
# For the time being, please create a *free* [GitHub account](https://github.com/signup). You do not need to sign up for the Pro version but GitHub does offer a [Student Developer Pack](https://education.github.com/pack), which you can apply to as a student.

# %% [markdown]
# # Google Colab
#
# For the first three weeks, we will use **Google Colab** for our coding exercises. The notebook `1-2_jupyter_and_python.ipynb` explains the reasoning in more detail.
#
# Please create a [Google Account](https://support.google.com/accounts/answer/27441?hl=en&co=GENIE.Platform%3DDesktop), if you do not have one already by our next class meeting. You do NOT need a paid account. Just make sure that you have enough space, like a gigabyte, to copy our course notebooks over.
